# %%
from tushare.pro import data_pro as ts
import pandas as pd

pro = ts.pro_api()
fields = 'ts_code,trade_date,turnover_rate,turnover_rate_f,volume_ratio,pe,pe_ttm,pb,ps,ps_ttm,dv_ratio,dv_ttm,total_share,float_share,total_mv,circ_mv'
df = pro.daily_basic(trade_date = '20100104', fields = fields)
df
# Out:
#         ts_code trade_date  ...      total_mv       circ_mv
# 0     600005.SH   20100104  ...  6.411609e+06  2.564718e+06
# 1     600006.SH   20100104  ...  1.382000e+06  1.382000e+06
# 2     300031.SZ   20100104  ...  2.834000e+05  5.668000e+04
# 3     300032.SZ   20100104  ...  4.258168e+05  8.522304e+04
# 4     300033.SZ   20100104  ...  5.011104e+05  1.002221e+05
# 5     300035.SZ   20100104  ...  3.004890e+05  6.058640e+04
# 6     002294.SZ   20100104  ...  1.042498e+06  2.617633e+05
# 7     002295.SZ   20100104  ...  3.346440e+05  8.532000e+04
# 8     002296.SZ   20100104  ...  4.014105e+05  1.011685e+05
# 9     002297.SZ   20100104  ...  3.006700e+05  7.587000e+04
# 10    002298.SZ   20100104  ...  2.647700e+05  6.739600e+04
# 11    002299.SZ   20100104  ...  1.055750e+06  8.446000e+04
# 12    002309.SZ   20100104  ...  8.259645e+05  1.658116e+05
# 13    002310.SZ   20100104  ...  5.700754e+05  1.320428e+05
# 14    002311.SZ   20100104  ...  8.404480e+05  1.680896e+05
# ...

# %%
a=0
a++
a
# Out:
#   File "<ipython-input-26-c6f39d017d94>", line 2
#     a++
#        ^
# SyntaxError: invalid syntax
